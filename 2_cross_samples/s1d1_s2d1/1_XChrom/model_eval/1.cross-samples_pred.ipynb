# %% [markdown]
# ## ⭐ cross-samples prediction test

# %%
import xchrom as xc
import scanpy as sc

# %%
#### 1- calculate cross-samples auROC & auPRC
metrics1 = xc.tl.crosssamples_aucprc(
    cell_embedding_ad='../../0_preprocess/processed_data/test_rna_harmony.h5ad',
    input_folder='../../0_preprocess/test_data',
    model_path='../model_train/train_out/E1000best_model.h5',
    output_path='./',
    cellembed_raw='X_pca_harmony',
    save_pred=True,
    scatter_plot=True
    )
# Out:
# 2025-08-18 22:30:14.059895: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2025-08-18 22:30:16.601363: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8800
# 2025-08-18 22:30:16.723935: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-08-18 22:31:53.520594: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 907046800 exceeds 10% of free system memory.
# Predict done! prediction shape is: (53735, 4220)
# Overall auROC: 0.8405, auPRC: 0.2351
# Per-cell auROC: 0.8052, auPRC: 0.1659
# Valid cells: 4220
# Per-peak auROC: 0.7585, auPRC: 0.1214
# Valid peaks: 53735
