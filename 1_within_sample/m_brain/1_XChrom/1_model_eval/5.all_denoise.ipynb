# %% [markdown]
# ## ⭐ all data denoise test

# %%
import xchrom as xc
import scanpy as sc

# %%
#### 5- calculate denoise ns & ls
metrics5 = xc.tl.denoise_nsls(
    cell_embedding_ad='../../0_data/processed_data/m_brain_paired_rna.h5ad',
    input_folder='../0_model_train/train_data',
    model_path='../0_model_train/train_out/E1000best_model.h5',
    output_path='./eval_out',
    cell_input_key='zscore32_perpc',
    cellembed_raw='X_pca',
    celltype='pc32_leiden',
    save_pred=True,
    plot_umap=True
    )
# Out:
# Converting adata.X to dense array. For large datasets, consider pre-computing and saving as sparse matrix.
# 2025-08-18 14:36:18.409957: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-18 14:36:20.585807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19276 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:31:00.0, compute capability: 8.6
# 2025-08-18 14:36:20.586860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22350 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:4b:00.0, compute capability: 8.6
# 2025-08-18 14:36:20.587869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 21285 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:98:00.0, compute capability: 8.6
# 2025-08-18 14:36:20.588855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 21265 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:b1:00.0, compute capability: 8.6
# 2025-08-18 14:36:21.782882: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2025-08-18 14:36:24.246482: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8800
# 2025-08-18 14:36:24.378046: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-08-18 14:37:43.148282: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 786587256 exceeds 10% of free system memory.
# Denoise done! denoise shape is: (40313, 4878)
# /home/miaoyuanyuan/miniconda3/envs/py3.8_tf2.6.0/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:842: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# neighbor score(100)=0.5155,label score(100)=0.7558
# neighbor score(50)=0.4498,label score(50)=0.8049
# neighbor score(10)=0.2885,label score(10)=0.8565
