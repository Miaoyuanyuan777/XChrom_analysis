# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('./history.pickle', 'rb') as f:
    history = pickle.load(f)
print(history.keys())
# Out:
# dict_keys(['loss', 'binary_accuracy', 'auc', 'pr', 'val_loss', 'val_binary_accuracy', 'val_auc', 'val_pr', 'neighbor_score', 'label_score'])

# %%
train_loss = history['loss']
train_auc = history['auc']
train_pr = history['pr']
val_loss = history['val_loss']
val_auc = history['val_auc']
val_pr = history['val_pr']
neighbor_score = history['neighbor_score']
label_score = history['label_score']

# %%
import matplotlib.pyplot as plt

# 绘制训练和验证损失
plt.figure(figsize=(15, 6))
plt.subplot(1,3, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# 绘制 PR 和 ROC AUC
plt.subplot(1,3, 2)
plt.plot(train_auc, label='Training AUC')
plt.plot(val_auc, label='Validation AUC')
plt.plot(train_pr, label='Training PR')
plt.plot(val_pr, label='Validation PR')
plt.title('Training/Validation PR and AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC/PR')
plt.legend()

plt.subplot(1,3,3)
plt.plot(neighbor_score, label='Neighbor Score')
plt.plot(label_score, label='Label Score')
plt.title('Neighbor and Label Score')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()
plt.savefig('./training_track.pdf', format='pdf', dpi=300)
plt.show()

# %%
with open('./history.pickle', 'rb') as f:
    history = pickle.load(f)
print(history.keys())
# Out:
# dict_keys(['loss', 'binary_accuracy', 'auc', 'pr', 'val_loss', 'val_binary_accuracy', 'val_auc', 'val_pr', 'neighbor_score', 'label_score'])

# %%
train_loss = history['loss']
train_auc = history['auc']
train_pr = history['pr']
val_loss = history['val_loss']
val_auc = history['val_auc']
val_pr = history['val_pr']

# %%
# 绘制训练和验证损失
plt.figure(figsize=(10, 6))
plt.subplot(1,2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# 绘制 PR 和 ROC AUC
plt.subplot(1,2, 2)
plt.plot(train_auc, label='Training AUC')
plt.plot(val_auc, label='Validation AUC')
plt.plot(train_pr, label='Training PR')
plt.plot(val_pr, label='Validation PR')
plt.title('Training/Validation PR and AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC/PR')
plt.legend()
# plt.savefig('./training_track.pdf', format='pdf', dpi=300)
plt.show()
